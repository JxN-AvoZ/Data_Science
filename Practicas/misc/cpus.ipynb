# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
import os

cpu_num = os.cpu_count()
print(f"Mi computadora tiene {cpu_num} núcleos de CPU")
# Out:
# Mi computadora tiene 12 núcleos de CPU

# %% [markdown]
# ## Texto e imágenes en un cuaderno
# ---
# En Jupyter Notebook puedes mezclar:
# * código;
# * texto;
# * imágenes.

# %%
import sys
sys.version
# Out:
# '3.12.12 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 20:16:04) [GCC 11.2.0]'

# %%
import pandas as pd
import matplotlib
import sklearn


print(pd.__version__)
print(matplotlib.__version__)
print(sklearn.__version__)
# Out:
# 2.3.3
# 3.10.8
# 1.7.2
